# %% [markdown]
# # 人脸替换技术选型
#
# 有几种人脸替换的形式：
#
# - ~~修复，圈掉当前照片人脸，inpainting，promotion，生成新的人脸~~ 不是我们需要的，比如fooocus inpainting face swap
# - ~~数字分身方向，比如 [FaceChain](https://github.com/modelscope/facechain/blob/main/README_ZH.md)~~ ，输出符合要求，但是技术条件存在问题
# - 无需Lora的换脸方案

# %% [markdown]
# ## fooocus
#
# TODO

# %% [markdown]
# ## FaceChain
#
# 阿里旗下 ModelScope 推出的开源应用 [FaceChain](https://github.com/modelscope/facechain)
#
# 是打造个人数字形象的深度学习模型工具，是奔着做完整的数字分身方向去的工具。
#
# 不过存在缺陷被排除选型了：
#
# - 需要1-10 张的照片做 lora 模型，每张照片 2 分钟以上
# - 固定模板情况下，生成很慢，中间多次失败，不稳定，很难想象数万个任务是否能正常运行完

# %%
from diffusers.utils import load_image,make_image_grid

make_image_grid([load_image("./p1.jpg"), load_image("./p2.jpg"),load_image("./p3.png")], rows=1, cols=3,resize=512)
# Out:
# <PIL.Image.Image image mode=RGB size=1536x512>
