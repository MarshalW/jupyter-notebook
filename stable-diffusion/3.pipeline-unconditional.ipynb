# %% [markdown]
# # pipeline 无条件生成图
#
# 无条件图像生成生成的图像看起来像是来自模型训练数据的随机样本，因为去噪过程不受任何其他上下文（如文本或图像）的指导。

# %%
from diffusers import DiffusionPipeline

model_path="/models/ddpm-church-256"
generator = DiffusionPipeline.from_pretrained(model_path).to("cuda")

image = generator().images[0]
image
# Out:
# Loading pipeline components...:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# 查看pipeline的配置。

# %%
generator
# Out:
# DDPMPipeline {
#   "_class_name": "DDPMPipeline",
#   "_diffusers_version": "0.24.0",
#   "_name_or_path": "/models/ddpm-church-256",
#   "scheduler": [
#     "diffusers",
#     "DDPMScheduler"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DModel"
#   ]
# }

# %% [markdown]
# 可以设置去噪点步骤数量，控制图像质量。设置步数少，出图快，但质量下降。

# %%
image = generator(num_inference_steps= 200 ).images[0]
image
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256>
